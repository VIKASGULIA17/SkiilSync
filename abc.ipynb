# %%
import pandas as pd

# %%
df=pd.read_csv('data/cleaned_job_data.csv')

# %%
df['Platform'].value_counts()
# Out:
# Platform
# Internshala      420
# FreshersWorld    100
# Name: count, dtype: int64
